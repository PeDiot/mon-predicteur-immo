# %% [markdown]
# # Attention, le code n'est pas complet

# %%
from google.colab import drive
drive.mount("/content/drive")
import os 
os.chdir("./drive/MyDrive/Business Data Challenge/business-data-challenge/code/cleaning/")
# !pip install rich
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rich in /usr/local/lib/python3.8/dist-packages (13.3.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from rich) (2.2.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from rich) (4.5.0)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in /usr/local/lib/python3.8/dist-packages (from rich) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.8/dist-packages (from markdown-it-py<3.0.0,>=2.1.0->rich) (0.1.2)

# %%
DATA_DIR = "../../data/"
ZIP_DIR = f"{DATA_DIR}dvf.zip"

# %%
import pandas as pd 
import zipfile
from rich import print
from pandas.core.frame import DataFrame
from typing import Tuple

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
def load_zip_dvf(zip_dir: str, year: int) -> DataFrame: 
    zf = zipfile.ZipFile(zip_dir) 
    file_name = f"dvf/{year}.csv"

    df = pd.read_csv(zf.open(file_name))
    return df 

df = load_zip_dvf(ZIP_DIR, year=2021)
# Out:
# <ipython-input-10-bb4de521fee2>:8: DtypeWarning: Columns (10,12,14,17,18,20,22,24,35,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   df = load_zip_dvf(ZIP_DIR, year=2021)

# %%
df.head()
# Out:
#   id_mutation date_mutation  numero_disposition nature_mutation  \
# 0      2021-1    2021-01-05                   1           Vente
# 1      2021-1    2021-01-05                   1           Vente
# 2      2021-2    2021-01-06                   1           Vente
# 3      2021-3    2021-01-04                   1           Vente
# 4      2021-4    2021-01-06                   1           Vente
#
#    valeur_fonciere  adresse_numero adresse_suffixe   adresse_nom_voie  \
# 0         185000.0          5080.0             NaN     CHE DE VOGELAS
# 1         185000.0          5080.0             NaN     CHE DE VOGELAS
# 2             10.0             NaN             NaN          ROUGEMONT
# 3         204332.0             7.0             NaN  ALL DES ECUREUILS
# 4         320000.0            87.0             NaN    RTE DE CERTINES
#
#   adresse_code_voie  code_postal code_commune    nom_commune code_departement  \
# 0              0471       1370.0         1426  Val-Revermont                1
# 1              0471       1370.0         1426  Val-Revermont                1
# 2              B043       1290.0         1042            Bey                1
# 3              0276       1310.0         1065        Buellas                1
# 4              0140       1250.0         1254      Montagnat                1
#
#    ancien_code_commune ancien_nom_commune     id_parcelle  ancien_id_parcelle  \
# 0                  NaN                NaN  01426312ZC0122                 NaN
# 1                  NaN                NaN  01426312ZC0122                 NaN
# 2                  NaN                NaN  010420000A0204                 NaN
# 3                  NaN                NaN  010650000B1325                 NaN
# 4                  NaN                NaN  01254000AZ0011                 NaN
#
#   numero_volume lot1_numero  lot1_surface_carrez lot2_numero  \
# 0           NaN         NaN                  NaN         NaN
# 1           NaN         NaN                  NaN         NaN
# 2           NaN         NaN                  NaN         NaN
# 3           NaN         NaN                  NaN         NaN
# 4           NaN         NaN                  NaN         NaN
#
#    lot2_surface_carrez lot3_numero  lot3_surface_carrez lot4_numero  \
# 0                  NaN         NaN                  NaN         NaN
# 1                  NaN         NaN                  NaN         NaN
# 2                  NaN         NaN                  NaN         NaN
# 3                  NaN         NaN                  NaN         NaN
# 4                  NaN         NaN                  NaN         NaN
#
#    lot4_surface_carrez  lot5_numero  lot5_surface_carrez  nombre_lots  \
# 0                  NaN          NaN                  NaN            0
# 1                  NaN          NaN                  NaN            0
# 2                  NaN          NaN                  NaN            0
# 3                  NaN          NaN                  NaN            0
# 4                  NaN          NaN                  NaN            0
#
#    code_type_local  type_local  surface_reelle_bati  \
# 0              1.0      Maison                 97.0
# 1              3.0  Dépendance                  NaN
# 2              NaN         NaN                  NaN
# 3              1.0      Maison                 88.0
# 4              3.0  Dépendance                  NaN
#
#    nombre_pieces_principales code_nature_culture   nature_culture  \
# 0                        5.0                   S             sols
# 1                        0.0                   S             sols
# 2                        NaN                  BT  taillis simples
# 3                        4.0                   S             sols
# 4                        0.0                   S             sols
#
#   code_nature_culture_speciale nature_culture_speciale  surface_terrain  \
# 0                          NaN                     NaN           2410.0
# 1                          NaN                     NaN           2410.0
# 2                          NaN                     NaN            530.0
# 3                          NaN                     NaN            866.0
# 4                          NaN                     NaN           1426.0
#
#    longitude   latitude
# 0   5.386094  46.327140
# 1   5.386094  46.327140
# 2   4.844368  46.224233
# 3   5.157688  46.200988
# 4   5.273260  46.156334

# %% [markdown]
# ### Cleaning de la base dvf21

# %%
def select_sales(df: DataFrame) -> DataFrame: 
    if "nature_mutation" not in df.columns: 
        raise ValueError("nature_mutation not in columns.")
    
    return df.loc[df.nature_mutation == "Vente", :] 
df_sales = select_sales(df)
df_sales.head()
# Out:
#   id_mutation date_mutation  numero_disposition nature_mutation  \
# 0      2021-1    2021-01-05                   1           Vente
# 1      2021-1    2021-01-05                   1           Vente
# 2      2021-2    2021-01-06                   1           Vente
# 3      2021-3    2021-01-04                   1           Vente
# 4      2021-4    2021-01-06                   1           Vente
#
#    valeur_fonciere  adresse_numero adresse_suffixe   adresse_nom_voie  \
# 0         185000.0          5080.0             NaN     CHE DE VOGELAS
# 1         185000.0          5080.0             NaN     CHE DE VOGELAS
# 2             10.0             NaN             NaN          ROUGEMONT
# 3         204332.0             7.0             NaN  ALL DES ECUREUILS
# 4         320000.0            87.0             NaN    RTE DE CERTINES
#
#   adresse_code_voie  code_postal code_commune    nom_commune code_departement  \
# 0              0471       1370.0         1426  Val-Revermont                1
# 1              0471       1370.0         1426  Val-Revermont                1
# 2              B043       1290.0         1042            Bey                1
# 3              0276       1310.0         1065        Buellas                1
# 4              0140       1250.0         1254      Montagnat                1
#
#    ancien_code_commune ancien_nom_commune     id_parcelle  ancien_id_parcelle  \
# 0                  NaN                NaN  01426312ZC0122                 NaN
# 1                  NaN                NaN  01426312ZC0122                 NaN
# 2                  NaN                NaN  010420000A0204                 NaN
# 3                  NaN                NaN  010650000B1325                 NaN
# 4                  NaN                NaN  01254000AZ0011                 NaN
#
#   numero_volume lot1_numero  lot1_surface_carrez lot2_numero  \
# 0           NaN         NaN                  NaN         NaN
# 1           NaN         NaN                  NaN         NaN
# 2           NaN         NaN                  NaN         NaN
# 3           NaN         NaN                  NaN         NaN
# 4           NaN         NaN                  NaN         NaN
#
#    lot2_surface_carrez lot3_numero  lot3_surface_carrez lot4_numero  \
# 0                  NaN         NaN                  NaN         NaN
# 1                  NaN         NaN                  NaN         NaN
# 2                  NaN         NaN                  NaN         NaN
# 3                  NaN         NaN                  NaN         NaN
# 4                  NaN         NaN                  NaN         NaN
#
#    lot4_surface_carrez  lot5_numero  lot5_surface_carrez  nombre_lots  \
# 0                  NaN          NaN                  NaN            0
# 1                  NaN          NaN                  NaN            0
# 2                  NaN          NaN                  NaN            0
# 3                  NaN          NaN                  NaN            0
# 4                  NaN          NaN                  NaN            0
#
#    code_type_local  type_local  surface_reelle_bati  \
# 0              1.0      Maison                 97.0
# 1              3.0  Dépendance                  NaN
# 2              NaN         NaN                  NaN
# 3              1.0      Maison                 88.0
# 4              3.0  Dépendance                  NaN
#
#    nombre_pieces_principales code_nature_culture   nature_culture  \
# 0                        5.0                   S             sols
# 1                        0.0                   S             sols
# 2                        NaN                  BT  taillis simples
# 3                        4.0                   S             sols
# 4                        0.0                   S             sols
#
#   code_nature_culture_speciale nature_culture_speciale  surface_terrain  \
# 0                          NaN                     NaN           2410.0
# 1                          NaN                     NaN           2410.0
# 2                          NaN                     NaN            530.0
# 3                          NaN                     NaN            866.0
# 4                          NaN                     NaN           1426.0
#
#    longitude   latitude
# 0   5.386094  46.327140
# 1   5.386094  46.327140
# 2   4.844368  46.224233
# 3   5.157688  46.200988
# 4   5.273260  46.156334

# %%
print(f"{df_sales.shape[0]} transactions associées à des ventes \n{df_sales.id_mutation.unique().shape[0]} identifiants uniques de mutation")
# Out:
# 4047675 transactions associées à des ventes
# 1500963 identifiants uniques de mutation

# %%
def remove_industrial_facilities(df: DataFrame) -> DataFrame: 
    if "code_type_local" not in df.columns: 
        raise ValueError("code_type_local not in columns.")
    
    return df.loc[
        (df.code_type_local >= 1) & 
        (df.code_type_local < 4), 
        :
    ] 
df_sales = remove_industrial_facilities(df_sales)
print(f"{df_sales.shape[0]} ventes d'appartements/maisons/dépendances")
# Out:
# 2415588 ventes d'appartements/maisons/dépendances

# %%
pd.crosstab(df_sales["type_local"], df_sales["code_type_local"], margins=True)
# Out:
# code_type_local     1.0     2.0      3.0      All
# type_local
# Appartement           0  605165        0   605165
# Dépendance            0       0  1030535  1030535
# Maison           779888       0        0   779888
# All              779888  605165  1030535  2415588

# %% [markdown]
# ### Cleaning de la base dvf21

# %%
# traitement des actes simples 
temp = df_sales.groupby("id_mutation").size()
not_duplicated = temp[temp==1].index.tolist()
not_duplicated

# %%
mutations_simples = df_sales.loc[df_sales.id_mutation.isin(not_duplicated), :]
mutations_simples.head()
# Out:
#    id_mutation date_mutation  numero_disposition nature_mutation  \
# 3       2021-3    2021-01-04                   1           Vente
# 14      2021-9    2021-01-04                   2           Vente
# 15     2021-10    2021-01-08                   1           Vente
# 16     2021-11    2021-01-07                   1           Vente
# 19     2021-13    2021-01-08                   1           Vente
#
#     valeur_fonciere  adresse_numero adresse_suffixe          adresse_nom_voie  \
# 3          204332.0             7.0             NaN         ALL DES ECUREUILS
# 14         226700.0           173.0             NaN  CHE DU MOULIN DE POLAIZE
# 15         185000.0            46.0             NaN    RUE DES GRANGES BONNET
# 16         114500.0           179.0             NaN          RUE DE LA MAIRIE
# 19         145000.0             8.0             NaN          IMP DE CHAMANDRE
#
#    adresse_code_voie  code_postal code_commune nom_commune code_departement  \
# 3               0276       1310.0         1065     Buellas                1
# 14              0164       1310.0         1301     Polliat                1
# 15              0161       1960.0         1289    Péronnas                1
# 16              0110       1340.0         1163    Foissiat                1
# 19              0255       1340.0         1163    Foissiat                1
#
#     ancien_code_commune ancien_nom_commune     id_parcelle  \
# 3                   NaN                NaN  010650000B1325
# 14                  NaN                NaN  01301000AA0289
# 15                  NaN                NaN  01289000AD0031
# 16                  NaN                NaN  01163000AB0302
# 19                  NaN                NaN  01163000WC0215
#
#     ancien_id_parcelle numero_volume lot1_numero  lot1_surface_carrez  \
# 3                  NaN           NaN         NaN                  NaN
# 14                 NaN           NaN         NaN                  NaN
# 15                 NaN           NaN         NaN                  NaN
# 16                 NaN           NaN         NaN                  NaN
# 19                 NaN           NaN         NaN                  NaN
#
#    lot2_numero  lot2_surface_carrez lot3_numero  lot3_surface_carrez  \
# 3          NaN                  NaN         NaN                  NaN
# 14         NaN                  NaN         NaN                  NaN
# 15         NaN                  NaN         NaN                  NaN
# 16         NaN                  NaN         NaN                  NaN
# 19         NaN                  NaN         NaN                  NaN
#
#    lot4_numero  lot4_surface_carrez  lot5_numero  lot5_surface_carrez  \
# 3          NaN                  NaN          NaN                  NaN
# 14         NaN                  NaN          NaN                  NaN
# 15         NaN                  NaN          NaN                  NaN
# 16         NaN                  NaN          NaN                  NaN
# 19         NaN                  NaN          NaN                  NaN
#
#     nombre_lots  code_type_local type_local  surface_reelle_bati  \
# 3             0              1.0     Maison                 88.0
# 14            0              1.0     Maison                 96.0
# 15            0              1.0     Maison                100.0
# 16            0              1.0     Maison                 85.0
# 19            0              1.0     Maison                 92.0
#
#     nombre_pieces_principales code_nature_culture nature_culture  \
# 3                         4.0                   S           sols
# 14                        3.0                 NaN            NaN
# 15                        4.0                   S           sols
# 16                        2.0                   S           sols
# 19                        1.0                   S           sols
#
#    code_nature_culture_speciale nature_culture_speciale  surface_terrain  \
# 3                           NaN                     NaN            866.0
# 14                          NaN                     NaN              NaN
# 15                          NaN                     NaN            703.0
# 16                          NaN                     NaN             87.0
# 19                          NaN                     NaN           2480.0
#
#     longitude   latitude
# 3    5.157688  46.200988
# 14   5.108604  46.244066
# 15   5.210226  46.187698
# 16   5.174845  46.368874
# 19   5.200760  46.405032

# %%
temp = df_sales.groupby("id_mutation").size()
duplica = temp[temp>1].index.tolist()
duplica

# %%
mutations_complexes = df_sales.loc[df_sales.id_mutation.isin(duplica), :]
mutations_complexes.head()
# Out:
#   id_mutation date_mutation  numero_disposition nature_mutation  \
# 0      2021-1    2021-01-05                   1           Vente
# 1      2021-1    2021-01-05                   1           Vente
# 4      2021-4    2021-01-06                   1           Vente
# 5      2021-4    2021-01-06                   1           Vente
# 7      2021-6    2021-01-04                   1           Vente
#
#    valeur_fonciere  adresse_numero adresse_suffixe adresse_nom_voie  \
# 0         185000.0          5080.0             NaN   CHE DE VOGELAS
# 1         185000.0          5080.0             NaN   CHE DE VOGELAS
# 4         320000.0            87.0             NaN  RTE DE CERTINES
# 5         320000.0            87.0             NaN  RTE DE CERTINES
# 7         176000.0           210.0             NaN  RUE GEORGE SAND
#
#   adresse_code_voie  code_postal code_commune            nom_commune  \
# 0              0471       1370.0         1426          Val-Revermont
# 1              0471       1370.0         1426          Val-Revermont
# 4              0140       1250.0         1254              Montagnat
# 5              0140       1250.0         1254              Montagnat
# 7              0820       1000.0         1344  Saint-Denis-lès-Bourg
#
#   code_departement  ancien_code_commune ancien_nom_commune     id_parcelle  \
# 0                1                  NaN                NaN  01426312ZC0122
# 1                1                  NaN                NaN  01426312ZC0122
# 4                1                  NaN                NaN  01254000AZ0011
# 5                1                  NaN                NaN  01254000AZ0011
# 7                1                  NaN                NaN  01344000AC0181
#
#    ancien_id_parcelle numero_volume lot1_numero  lot1_surface_carrez  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
# 5                 NaN           NaN         NaN                  NaN
# 7                 NaN           NaN        39.0                  NaN
#
#   lot2_numero  lot2_surface_carrez lot3_numero  lot3_surface_carrez  \
# 0         NaN                  NaN         NaN                  NaN
# 1         NaN                  NaN         NaN                  NaN
# 4         NaN                  NaN         NaN                  NaN
# 5         NaN                  NaN         NaN                  NaN
# 7         NaN                  NaN         NaN                  NaN
#
#   lot4_numero  lot4_surface_carrez  lot5_numero  lot5_surface_carrez  \
# 0         NaN                  NaN          NaN                  NaN
# 1         NaN                  NaN          NaN                  NaN
# 4         NaN                  NaN          NaN                  NaN
# 5         NaN                  NaN          NaN                  NaN
# 7         NaN                  NaN          NaN                  NaN
#
#    nombre_lots  code_type_local   type_local  surface_reelle_bati  \
# 0            0              1.0       Maison                 97.0
# 1            0              3.0   Dépendance                  NaN
# 4            0              3.0   Dépendance                  NaN
# 5            0              1.0       Maison                168.0
# 7            1              2.0  Appartement                 71.0
#
#    nombre_pieces_principales code_nature_culture nature_culture  \
# 0                        5.0                   S           sols
# 1                        0.0                   S           sols
# 4                        0.0                   S           sols
# 5                        5.0                   S           sols
# 7                        3.0                 NaN            NaN
#
#   code_nature_culture_speciale nature_culture_speciale  surface_terrain  \
# 0                          NaN                     NaN           2410.0
# 1                          NaN                     NaN           2410.0
# 4                          NaN                     NaN           1426.0
# 5                          NaN                     NaN           1426.0
# 7                          NaN                     NaN              NaN
#
#    longitude   latitude
# 0   5.386094  46.327140
# 1   5.386094  46.327140
# 4   5.273260  46.156334
# 5   5.273260  46.156334
# 7   5.200117  46.210292

# %%
def get_data_types(dataframe):
    ''''
    Renvoie tous les data types dans un pd df.
    '''
    return [str(dt) for dt in dataframe.dtypes.unique()]

get_data_types(df)
# Out:
# ['object', 'int64', 'float64']

# %% [markdown]
# #### On teste deux fonctions différentes

# %%
def List_type(df: DataFrame, format: str):

  ''''
  fonction créant une liste de toutes les variables de df étant à un format particulier (ex. float64). 
  '''
  temp1 = df.dtypes
  temp2 = temp1.to_frame(name = 'Type')
  temp3 = temp2.loc[temp2['Type'] == {format}]
  data_top = temp3.head()
  result = list(data_top.index)
  return result

# %%
def get_variable_names(dataframe, data_type):
    """
    Returns a list of variable names in a Pandas DataFrame that match a given format string.
    """
    return [col for col in dataframe.columns if dataframe[col].dtype == data_type]

# %%
list_var_float = get_variable_names(df, 'float64')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-80db5dfd65bf> in <module>
# ----> 1 get_variable_names(df, float64)
#
# <ipython-input-137-cb508972842c> in get_variable_names(dataframe, format_str)
#       3     Returns a list of variable names in a Pandas DataFrame that match a given format string.
#       4     """
# ----> 5     return [col for col in dataframe.columns if format_str.format(col) == col]
#
# <ipython-input-137-cb508972842c> in <listcomp>(.0)
#       3     Returns a list of variable names in a Pandas DataFrame that match a given format string.
#       4     """
# ----> 5     return [col for col in dataframe.columns if format_str.format(col) == col]
#
# AttributeError: 'list' object has no attribute 'format'

# %% [markdown]
# #### On le fait a la mano en attendant

# %%
#
result = df.dtypes
result = result.to_frame(name = 'type')
quanti = result.loc[result['type'] == 'float64']
data_top = quanti.head()
quanti = list(data_top.index)
quanti
#
result = df.dtypes
result = result.to_frame(name = 'type')
quali = result.loc[result['type'] == 'object']
data_top = quali.head()
quali = list(data_top.index)
quali.remove('id_mutation')

# %%
# Application de la solution 4 sur les mutations dites complexes (cf. Coulondre, 2019)

var_quali = ['type_local', 'nature_mutation'] # add more here
for var in var_quali: 
  clean_quali = mutations_complexes.groupby(['id_mutation', 'valeur_fonciere'])[f'{var}'].apply(lambda x: ','.join(x)).reset_index()

var_quanti = ['nombre_lots','surface_reelle_bati'] # add more here
for var in var_quanti:
  clean_quanti = mutations_complexes.groupby(['id_mutation', 'valeur_fonciere'])[f'{var}'].sum()

# %%
# Select columns and merge in a df 
mutations_complexes_clean = pd.merge(clean_quanti, clean_quali, on=['id_mutation'])
mutations_complexes_clean.head(10)
# Out:
#     id_mutation  surface_reelle_bati  valeur_fonciere    nature_mutation
# 0        2021-1                 97.0         185000.0        Vente,Vente
# 1      2021-100                232.0         140000.0        Vente,Vente
# 2     2021-1000                 86.0          72150.0        Vente,Vente
# 3    2021-10000                117.0         730000.0        Vente,Vente
# 4  2021-1000000                 39.0         141240.0  Vente,Vente,Vente
# 5  2021-1000001                 91.0         184000.0        Vente,Vente
# 6  2021-1000003                156.0         120000.0        Vente,Vente
# 7  2021-1000009                106.0         190000.0        Vente,Vente
# 8  2021-1000014                 70.0         628000.0  Vente,Vente,Vente
# 9  2021-1000015                 66.0         395000.0        Vente,Vente

# %%
print(f"la taille de la mutations_complexes avant était {len(mutations_complexes)} et est maintenant de {len(mutations_complexes)}")
# Out:
# la taille de la mutations_complexes avant était 1910045 et est maintenant de 1910045

# %%
# Merge/append again with no_duplica since duplica has been treated
df_mutation_clean = mutations_simples.append(mutations_complexes_clean)
df_mutation_clean.head(10)
# Out:
#    id_mutation date_mutation  numero_disposition nature_mutation  \
# 3       2021-3    2021-01-04                 1.0           Vente
# 14      2021-9    2021-01-04                 2.0           Vente
# 15     2021-10    2021-01-08                 1.0           Vente
# 16     2021-11    2021-01-07                 1.0           Vente
# 19     2021-13    2021-01-08                 1.0           Vente
# 24     2021-14    2021-01-07                 1.0           Vente
# 28     2021-16    2021-01-18                 1.0           Vente
# 45     2021-20    2021-01-04                 1.0           Vente
# 46     2021-21    2021-01-04                 1.0           Vente
# 59     2021-27    2021-01-11                 1.0           Vente
#
#     valeur_fonciere  adresse_numero adresse_suffixe  \
# 3          204332.0             7.0             NaN
# 14         226700.0           173.0             NaN
# 15         185000.0            46.0             NaN
# 16         114500.0           179.0             NaN
# 19         145000.0             8.0             NaN
# 24         169600.0           153.0             NaN
# 28         178600.0           745.0             NaN
# 45         130000.0            68.0             NaN
# 46          10000.0            32.0             NaN
# 59         150000.0           870.0             NaN
#
#               adresse_nom_voie adresse_code_voie  code_postal code_commune  \
# 3            ALL DES ECUREUILS              0276       1310.0         1065
# 14    CHE DU MOULIN DE POLAIZE              0164       1310.0         1301
# 15      RUE DES GRANGES BONNET              0161       1960.0         1289
# 16            RUE DE LA MAIRIE              0110       1340.0         1163
# 19            IMP DE CHAMANDRE              0255       1340.0         1163
# 24           CHE DES MILLETTES              0135       1160.0         1151
# 28             RTE DES BAISSES              0027       1570.0         1159
# 45          LOT LES JACQUEMINS              A008       1370.0         1350
# 46  AV DES ANCIENS COMBATTANTS              0231       1000.0         1053
# 59             RUE DE MAJORNAS              0150       1440.0         1451
#
#               nom_commune code_departement  ancien_code_commune  \
# 3                 Buellas                1                  NaN
# 14                Polliat                1                  NaN
# 15               Péronnas                1                  NaN
# 16               Foissiat                1                  NaN
# 19               Foissiat                1                  NaN
# 24               Druillat                1                  NaN
# 28               Feillens                1                  NaN
# 45  Saint-Étienne-du-Bois                1                  NaN
# 46        Bourg-en-Bresse                1                  NaN
# 59                 Viriat                1                  NaN
#
#    ancien_nom_commune     id_parcelle  ancien_id_parcelle numero_volume  \
# 3                 NaN  010650000B1325                 NaN           NaN
# 14                NaN  01301000AA0289                 NaN           NaN
# 15                NaN  01289000AD0031                 NaN           NaN
# 16                NaN  01163000AB0302                 NaN           NaN
# 19                NaN  01163000WC0215                 NaN           NaN
# 24                NaN  011510000C0517                 NaN           NaN
# 28                NaN  01159000AD0648                 NaN           NaN
# 45                NaN  013500000B1506                 NaN           NaN
# 46                NaN  01053000AE0286                 NaN           NaN
# 59                NaN  01451000BI0213                 NaN           NaN
#
#    lot1_numero  lot1_surface_carrez lot2_numero  lot2_surface_carrez  \
# 3          NaN                  NaN         NaN                  NaN
# 14         NaN                  NaN         NaN                  NaN
# 15         NaN                  NaN         NaN                  NaN
# 16         NaN                  NaN         NaN                  NaN
# 19         NaN                  NaN         NaN                  NaN
# 24         NaN                  NaN         NaN                  NaN
# 28         NaN                  NaN         NaN                  NaN
# 45         NaN                  NaN         NaN                  NaN
# 46        13.0                  NaN         NaN                  NaN
# 59         NaN                  NaN         NaN                  NaN
#
#    lot3_numero  lot3_surface_carrez lot4_numero  lot4_surface_carrez  \
# 3          NaN                  NaN         NaN                  NaN
# 14         NaN                  NaN         NaN                  NaN
# 15         NaN                  NaN         NaN                  NaN
# 16         NaN                  NaN         NaN                  NaN
# 19         NaN                  NaN         NaN                  NaN
# 24         NaN                  NaN         NaN                  NaN
# 28         NaN                  NaN         NaN                  NaN
# 45         NaN                  NaN         NaN                  NaN
# 46         NaN                  NaN         NaN                  NaN
# 59         NaN                  NaN         NaN                  NaN
#
#     lot5_numero  lot5_surface_carrez  nombre_lots  code_type_local  \
# 3           NaN                  NaN          0.0              1.0
# 14          NaN                  NaN          0.0              1.0
# 15          NaN                  NaN          0.0              1.0
# 16          NaN                  NaN          0.0              1.0
# 19          NaN                  NaN          0.0              1.0
# 24          NaN                  NaN          0.0              1.0
# 28          NaN                  NaN          0.0              1.0
# 45          NaN                  NaN          0.0              1.0
# 46          NaN                  NaN          1.0              3.0
# 59          NaN                  NaN          0.0              1.0
#
#     type_local  surface_reelle_bati  nombre_pieces_principales  \
# 3       Maison                 88.0                        4.0
# 14      Maison                 96.0                        3.0
# 15      Maison                100.0                        4.0
# 16      Maison                 85.0                        2.0
# 19      Maison                 92.0                        1.0
# 24      Maison                 98.0                        4.0
# 28      Maison                110.0                        4.0
# 45      Maison                 51.0                        2.0
# 46  Dépendance                  NaN                        0.0
# 59      Maison                100.0                        5.0
#
#    code_nature_culture nature_culture code_nature_culture_speciale  \
# 3                    S           sols                          NaN
# 14                 NaN            NaN                          NaN
# 15                   S           sols                          NaN
# 16                   S           sols                          NaN
# 19                   S           sols                          NaN
# 24                   S           sols                          NaN
# 28                   S           sols                          NaN
# 45                   S           sols                          NaN
# 46                 NaN            NaN                          NaN
# 59                   S           sols                          NaN
#
#    nature_culture_speciale  surface_terrain  longitude   latitude
# 3                      NaN            866.0   5.157688  46.200988
# 14                     NaN              NaN   5.108604  46.244066
# 15                     NaN            703.0   5.210226  46.187698
# 16                     NaN             87.0   5.174845  46.368874
# 19                     NaN           2480.0   5.200760  46.405032
# 24                     NaN            303.0   5.297663  46.069603
# 28                     NaN            472.0   4.888266  46.344279
# 45                     NaN            314.0   5.298291  46.284649
# 46                     NaN              NaN   5.214477  46.202725
# 59                     NaN            385.0   5.216355  46.221904

# %%
## TO DO/
# différentes vérifications à faire 
# taille des df
# voir si on perd des id ou pas (on supp. des doublons donc on doit en perdre un minimum)
